# %%
import pandas as pd

# %%
df1 = pd.read_csv("D:/lab2/data1.csv")
df2 = pd.read_csv("D:/lab2/data2.csv")
df3 = pd.read_csv("D:/lab2/data3.csv")
df4 = pd.read_csv("D:/lab2/data4.csv")
df5 = pd.read_csv("D:/lab2/data5.csv")

# %%
df6 = pd.read_csv("D:/lab2/jobs_clean.csv")
df7 = pd.read_csv("D:/lab2/dat.csv")
df8 = pd.read_csv("D:/lab2/data.csv")

# %%
df = pd.concat([df1, df2, df3, df4, df5], ignore_index=True)

# %%
df = df.drop(columns=["benefits", "applyType","applyUrl","companyId","posterProfileUrl","posterFullName","salary","sector","applicationsCount","experienceLevel"])

# %%
data = df

# %%
df7.insert(
    df7.columns.get_loc("jobUrl") + 1,
    "companyName",
    None
)

df7.insert(
    df7.columns.get_loc("jobUrl") + 2,
    "companyURL",
    None
)

# %%
df7.head()
# Out:
#                                                title       location  \
# 0  Product Scraping Python→ WooCommerce CSV (ACF ...          China
# 1  Developer Wanted – Fund Intelligence Dashboard...            ESP
# 2  Data Collection Specialist Needed for Google R...            AUS
# 3                     Website Scraper for RV rentals  United States
# 4  Need help with data analytics from December 20...  United States
#
#               postedTime               publishedAt  \
# 0  Posted 17 minutes ago  2025-12-02T05:44:15.600Z
# 1  Posted 25 minutes ago  2025-12-02T08:36:01.977Z
# 2  Posted 52 minutes ago  2025-12-02T08:09:23.409Z
# 3  Posted 53 minutes ago  2025-12-02T08:08:03.139Z
# 4     Posted 4 hours ago  2025-12-02T04:44:17.128Z
#
#                                               jobUrl companyName companyURL  \
# 0  https://www.upwork.com/jobs/Product-Scraping-P...        None       None
# 1  https://www.upwork.com/jobs/Developer-Wanted-F...        None       None
# ...

# %%
dataset = pd.concat([df8, df6, df7], ignore_index=True)

# %%
dataset.head()
# Out:
#                                                title          location  \
# 0                          Machine Learning Engineer  Indianapolis, IN
# 1                         Business Reporting Analyst  Indianapolis, IN
# 2  AI Engineer / Data Engineer (Indianapolis, IN ...  Indianapolis, IN
# 3  Computational Infrastructure Scientist – Biolo...  Indianapolis, IN
# 4                                      Data Engineer  Indianapolis, IN
#
#      postedTime publishedAt  \
# 0   2 weeks ago  2025-11-11
# 1    2 days ago  2025-11-29
# 2   2 weeks ago  2025-11-12
# 3    1 week ago  2025-11-20
# 4  17 hours ago  2025-12-02
#
#                                               jobUrl            companyName  \
# 0  https://www.linkedin.com/jobs/view/machine-lea...                 Elanco
# 1  https://www.linkedin.com/jobs/view/business-re...           Spot Freight
# 2  https://www.linkedin.com/jobs/view/ai-engineer...       Moser Consulting
# ...

# %%
dataset.shift()
# Out:
#                                                   title          location  \
# 0                                                  None              None
# 1                             Machine Learning Engineer  Indianapolis, IN
# 2                            Business Reporting Analyst  Indianapolis, IN
# 3     AI Engineer / Data Engineer (Indianapolis, IN ...  Indianapolis, IN
# 4     Computational Infrastructure Scientist – Biolo...  Indianapolis, IN
# ...                                                 ...               ...
# 4319  Freelancer Needed – Real Estate Owners Researc...     United States
# 4320  Freelancers Needed for Tele-Pharmacy (Canada) ...         Australia
# 4321         Content Copy-Paste Job for Google Document     United States
# 4322       Virtual Assistant for Airbnb Data Collection               GBR
# 4323  Web Scraping Specialist Needed for HomeAdvisor...     United States
#
#               postedTime               publishedAt  \
# ...

# %%
dataset.to_csv("D:/lab2/final_data.csv", index=False)
